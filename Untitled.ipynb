# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
img = cv2.imread('./data/FERG_DB_256/bonnie/bonnie_anger/bonnie_anger_1588.png')

# %%
tmp = 2.0*img/(255.0) - 1

# %%
plt.imshow(tmp, vmin=-1, vmax=1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# img = Image.open('./data/FERG_DB_256/bonnie/bonnie_anger/bonnie_anger_1588.png')

# %%
plt.imshow(img)

# %%
plt.imshow(img.resize((128,128)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-666a319db570> in <module>
# ----> 1 plt.imshow(img.resize((128,128)))
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...
